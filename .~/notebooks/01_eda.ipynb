# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# **Goal (Phase 1):** understand the dataset well enough to justify every cleaning and modeling decision that follows.
#
# ### Checklist
# - [ ] Load the raw data; check shape, dtypes, and `df.head()`
# - [ ] Find the `TotalCharges` problem (dtype + blanks). Which rows are blank? What do they have in common?
# - [ ] Target balance: what % of customers churn? (This decides your metrics.)
# - [ ] Univariate plots: tenure, MonthlyCharges, Contract, InternetService, PaymentMethod
# - [ ] Bivariate: churn rate vs. contract type, tenure buckets, payment method
# - [ ] Write **3–4 hypotheses** about what drives churn (markdown cell at the bottom)
# - [ ] Promote your cleaning steps into `src/data.py::clean()` and tick Phase 1 in the README

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Make `src` importable when running from the notebooks/ folder
sys.path.append(str(Path.cwd().parent))

import matplotlib.pyplot as plt  # noqa: F401
import pandas as pd  # noqa: F401
import seaborn as sns  # noqa: F401

from src.data import load_raw

df = load_raw()
df.shape

# %% [markdown]
# ## Hypotheses about churn drivers
#
# 1. ...
# 2. ...
# 3. ...
